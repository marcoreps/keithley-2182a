# %%
import pandas as pd
from lpsd import lpsd, flattop # https://gitlab.com/uhh-gwd/lpsd
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from matplotlib.ticker import EngFormatter
import numpy as np

# Set up plot
fig,ax = plt.subplots(figsize=(16,9))
plt.loglog()
plt.xlim([0.0001,10])
plt.ylim([0.000000001,0.0000006])
plt.xlabel('frequency [Hz]')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.4f'))
ax.yaxis.set_major_formatter(EngFormatter())
ax.yaxis.set_minor_formatter(EngFormatter())
plt.ylabel(r'Noise [$\frac{V}{\sqrt{Hz}}$]')
plt.grid(True, which="both")
plt.title('Shorted Keithley 2182A Noise, NPLC vs reading output rate')


# Array from .csv
df = pd.read_csv('https://raw.githubusercontent.com/marcoreps/keithley-2182a/refs/heads/main/20240425-231708_Keithley_2182a_short_NPLC5.csv', skiprows=30, names=["2182a_volt",])
spectrum = lpsd(df['2182a_volt'], sample_rate=10, n_frequencies=100000, n_averages=300000, window_function=flattop.HFT90D, overlap = flattop.olap_dict["HFT90D"], detrending_order=1)
plt.plot(spectrum.index, spectrum["asd"], label='Loaner Keithley 2182A, NPLC 5, AZER ON, assuming 5 NPLC')

# Array from .csv
df = pd.read_csv('https://raw.githubusercontent.com/marcoreps/keithley-2182a/refs/heads/main/20240425-231708_Keithley_2182a_short_NPLC5.csv', skiprows=30, names=["2182a_volt",])
spectrum = lpsd(df['2182a_volt'], sample_rate=2.143, n_frequencies=100000, n_averages=300000, window_function=flattop.HFT90D, overlap = flattop.olap_dict["HFT90D"], detrending_order=1)
plt.plot(spectrum.index, spectrum["asd"], label='Loaner Keithley 2182A, NPLC 5, AZER ON, assuming reading output rate')


# Array from .csv
df = pd.read_csv('https://raw.githubusercontent.com/marcoreps/keithley-2182a/refs/heads/main/20240419-154946_Keithley_2182a_short_NPLC5.csv', skiprows=30, names=["2182a_volt",])
spectrum = lpsd(df['2182a_volt'], sample_rate=10, n_frequencies=100000, n_averages=300000, window_function=flattop.HFT90D, overlap = flattop.olap_dict["HFT90D"], detrending_order=1)
plt.plot(spectrum.index, spectrum["asd"], label='Loaner Keithley 2182A, NPLC 5, AZER OFF, assuming 5 NPLC')

# Array from .csv
df = pd.read_csv('https://raw.githubusercontent.com/marcoreps/keithley-2182a/refs/heads/main/20240419-154946_Keithley_2182a_short_NPLC5.csv', skiprows=30, names=["2182a_volt",])
spectrum = lpsd(df['2182a_volt'], sample_rate=4, n_frequencies=100000, n_averages=300000, window_function=flattop.HFT90D, overlap = flattop.olap_dict["HFT90D"], detrending_order=1)
plt.plot(spectrum.index, spectrum["asd"], label='Loaner Keithley 2182A, NPLC 5, AZER OFF, assuming reading output rate')

plt.legend()

# %%
import pandas as pd
from lpsd import lpsd, flattop # https://gitlab.com/uhh-gwd/lpsd
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from matplotlib.ticker import EngFormatter
import numpy as np

# Set up plot
fig,ax = plt.subplots(figsize=(16,9))
plt.loglog()
plt.xlim([0.0001,10])
plt.ylim([0.000000001,0.0000006])
plt.xlabel('frequency [Hz]')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.4f'))
ax.yaxis.set_major_formatter(EngFormatter())
ax.yaxis.set_minor_formatter(EngFormatter())
plt.ylabel(r'Noise [$\frac{V}{\sqrt{Hz}}$]')
plt.grid(True, which="both")
plt.title('Shorted 2182A Noise, assuming NPLC setting as sample rate')

# Array from .csv
df = pd.read_csv('https://raw.githubusercontent.com/marcoreps/keithley-2182a/refs/heads/main/20241123-203734_Keithley_2182a_short_NPLC1.csv')
spectrum = lpsd(df['2182a_volt'], sample_rate=50, n_frequencies=100000, n_averages=300000, window_function=flattop.HFT90D, overlap = flattop.olap_dict["HFT90D"], detrending_order=1)
plt.plot(spectrum.index, spectrum["asd"], label='My Keithley 2182A, NPLC 1, LPAS OFF, DFIL OFF, AZER ON, FAZ ON, LSYNc OFF')

# Array from .csv
df = pd.read_csv('https://raw.githubusercontent.com/marcoreps/keithley-2182a/refs/heads/main/20241127-155127_Keithley_2182a_short_NPLC5.csv')
spectrum = lpsd(df['2182a_volt'], sample_rate=10, n_frequencies=100000, n_averages=300000, window_function=flattop.HFT90D, overlap = flattop.olap_dict["HFT90D"], detrending_order=1)
plt.plot(spectrum.index, spectrum["asd"], label='My Keithley 2182A, NPLC 5, LPAS OFF, DFIL OFF, AZER ON, FAZ ON, LSYNc OFF')

# Array from .csv
df = pd.read_csv('https://raw.githubusercontent.com/marcoreps/keithley-2182a/refs/heads/main/20240419-154946_Keithley_2182a_short_NPLC5.csv', skiprows=20, names=["2182a_volt",])
spectrum = lpsd(df['2182a_volt'], sample_rate=10, n_frequencies=100000, n_averages=300000, window_function=flattop.HFT90D, overlap = flattop.olap_dict["HFT90D"], detrending_order=1)
plt.plot(spectrum.index, spectrum["asd"], label='Loaner Keithley 2182A, NPLC 5, LPAS OFF, DFIL OFF, AZER OFF, FAZ ON, LSYNc ON')

# Array from .csv
df = pd.read_csv('https://raw.githubusercontent.com/marcoreps/keithley-2182a/refs/heads/main/20240425-003650_Keithley_2182a_short_NPLC5.csv', skiprows=20, names=["2182a_volt",])
spectrum = lpsd(df['2182a_volt'], sample_rate=10, n_frequencies=100000, n_averages=300000, window_function=flattop.HFT90D, overlap = flattop.olap_dict["HFT90D"], detrending_order=1)
plt.plot(spectrum.index, spectrum["asd"], label='Loaner Keithley 2182A, NPLC 5, LPAS OFF, DFIL OFF, AZER OFF, FAZ ON, LSYNc ON')

# Array from .csv
df = pd.read_csv('https://raw.githubusercontent.com/marcoreps/keithley-2182a/refs/heads/main/20241129-101101_Keithley_2182a_short_NPLC1.csv', skiprows=30, names=["2182a_volt",])
spectrum = lpsd(df['2182a_volt'], sample_rate=50, n_frequencies=100000, n_averages=300000, window_function=flattop.HFT90D, overlap = flattop.olap_dict["HFT90D"], detrending_order=1)
plt.plot(spectrum.index, spectrum["asd"], label='My Keithley 2182A, NPLC 1, LPAS OFF, DFIL OFF, AZER ON, FAZ ON, LSYNc ON')

plt.legend()
